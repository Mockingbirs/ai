# %%
import pandas as pd
import random
import os
import numpy as np

from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier, Pool
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings, random
warnings.filterwarnings(action='ignore')

from sklearn.metrics import log_loss
from sklearn.preprocessing import StandardScaler
from category_encoders.ordinal import OrdinalEncoder
from sklearn.model_selection import StratifiedKFold

from sklearn.cluster import KMeans
from catboost import CatBoostClassifier, Pool, CatBoostRegressor
from sklearn.model_selection import train_test_split

import catboost as cb
import optuna
from sklearn.metrics import accuracy_score
from optuna.samplers import TPESampler

from teddynote import models



import pandas as pd
import random
import os
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from sklearn import tree # 의사결정트리
from sklearn import preprocessing

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

#sklearn 모델의 동일한 결과 출력을 위해 선언합니다.
np.random.seed(42)

# %%
class CFG:
    SEED = 42

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(CFG.SEED) # Seed 고정

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
def get_x_y(df):
    if 'class' in df.columns:
        df_x = df.drop(columns=['id', 'class','father','mother','gender'])
        df_y = df['class']
        return df_x, df_y
    else:
        df_x = df.drop(columns=['id','father','mother','gender'])
        return df_x

train_x, train_y = get_x_y(train)
test_x = get_x_y(test)
train_x
# Out:
#      trait SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_07 SNP_08 SNP_09  \
# 0        2    G G    A G    A A    G A    C A    A A    A A    G G    A A
# 1        2    A G    A G    C A    A A    A A    A G    A A    G A    A A
# 2        2    G G    G G    A A    G A    C C    G G    A A    G A    G A
# 3        1    A A    G G    A A    G A    A A    G G    G G    A A    G G
# 4        2    G G    G G    C C    A A    C C    A A    A A    A A    A A
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 257      2    A G    A G    A A    G A    C C    A G    A A    G A    A A
# 258      2    G G    A A    C A    A A    A A    A G    G A    G A    A A
# 259      1    A G    G G    A A    G A    A A    A G    G G    G A    G A
# 260      1    A A    G G    A A    G A    A A    G G    G G    A A    G A
# 261      2    G G    A G    C A    G G    C C    A G    A A    A A    A A
#
#     SNP_10 SNP_11 SNP_12 SNP_13 SNP_14 SNP_15
# 0      G G    A G    A A    A A    A A    A A
# 1      A G    A A    G A    G G    A A    A A
# 2      A G    A A    A A    A A    A A    A A
# 3      A G    G G    G G    G G    A A    G G
# 4      G G    A A    A A    A G    A A    G A
# ..     ...    ...    ...    ...    ...    ...
# 257    G G    A G    G A    A A    A A    A A
# 258    A G    A G    A A    A G    A A    G A
# 259    A A    G G    G G    G G    C A    G G
# 260    A G    A G    G A    G G    C A    G G
# 261    G G    A A    A A    G G    A A    G A
#
# [262 rows x 16 columns]

# %%
test_x
# Out:
#      trait SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_07 SNP_08 SNP_09  \
# 0        1    A G    G G    A A    G A    A A    A G    G G    G A    G A
# 1        2    G G    A G    C C    G G    C C    A A    A A    A A    A A
# 2        2    G G    A G    A A    A A    C A    A G    A A    A A    A A
# 3        2    G G    A G    C A    A A    C C    A A    A A    A A    A A
# 4        1    A A    G G    A A    G G    A A    G G    G G    A A    G G
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 170      2    A G    G G    C C    A A    C A    A G    A A    G G    A A
# 171      2    G G    A A    A A    A A    C A    A G    A A    A A    A A
# 172      2    G G    A A    A A    A A    C A    A G    A A    A A    A A
# 173      2    A G    G G    C A    G A    C C    G G    A A    G A    A A
# 174      2    G G    G G    C C    G A    C A    A A    G A    G G    A A
#
#     SNP_10 SNP_11 SNP_12 SNP_13 SNP_14 SNP_15
# 0      A G    A G    G A    G G    C A    G A
# 1      G G    A G    A A    A A    A A    A A
# 2      A G    A A    G A    G G    A A    G G
# 3      G G    A A    G A    A G    A A    A A
# 4      A G    G G    G A    G G    A A    G G
# ..     ...    ...    ...    ...    ...    ...
# 170    G G    G G    A A    A A    A A    G A
# 171    A G    A A    A A    A G    A A    G A
# 172    G G    A G    A A    A G    A A    G G
# 173    G G    A G    A A    A A    A A    A A
# 174    G G    G G    A A    A A    A A    A A
#
# [175 rows x 16 columns]

# %%
train_y
# Out:
# 0      B
# 1      C
# 2      B
# 3      A
# 4      C
#       ..
# 257    B
# 258    C
# 259    A
# 260    A
# 261    B
# Name: class, Length: 262, dtype: object

# %%
class_le = preprocessing.LabelEncoder()
snp_le = preprocessing.LabelEncoder()
snp_col = [f'SNP_{str(x).zfill(2)}' for x in range(1,16)]

snp_data = []
for col in snp_col:
    snp_data += list(train_x[col].values)

train_y = class_le.fit_transform(train_y)
snp_le.fit(snp_data)
# Out:
# LabelEncoder()

# %%
for col in train_x.columns:
    if col in snp_col:
        train_x[col] = snp_le.transform(train_x[col])
        test_x[col] = snp_le.transform(test_x[col])

# %%
train_x
# Out:
#      trait  SNP_01  SNP_02  SNP_03  SNP_04  SNP_05  SNP_06  SNP_07  SNP_08  \
# 0        2       5       1       0       4       2       0       0       5
# 1        2       1       1       2       0       0       1       0       4
# 2        2       5       5       0       4       3       5       0       4
# 3        1       0       5       0       4       0       5       5       0
# 4        2       5       5       3       0       3       0       0       0
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 257      2       1       1       0       4       3       1       0       4
# 258      2       5       0       2       0       0       1       4       4
# 259      1       1       5       0       4       0       1       5       4
# 260      1       0       5       0       4       0       5       5       0
# 261      2       5       1       2       5       3       1       0       0
#
#      SNP_09  SNP_10  SNP_11  SNP_12  SNP_13  SNP_14  SNP_15
# 0         0       5       1       0       0       0       0
# 1         0       1       0       4       5       0       0
# 2         4       1       0       0       0       0       0
# 3         5       1       5       5       5       0       5
# 4         0       5       0       0       1       0       4
# ..      ...     ...     ...     ...     ...     ...     ...
# 257       0       5       1       4       0       0       0
# 258       0       1       1       0       1       0       4
# 259       4       0       5       5       5       2       5
# 260       4       1       1       4       5       2       5
# 261       0       5       0       0       5       0       4
#
# [262 rows x 16 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.2)

# %%
#학습데이터로 모델 학습
model = tree.DecisionTreeClassifier(random_state = 42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
preds = model.predict(X_test)
print('done')
# Out:
# done

# %%
accuracy_score(y_test, preds)
# Out:
# 0.9433962264150944

# %%
def elbow(data, length):
    sse = [] # sum of squre error 오차제곱합
    for i in range(1, length):
        kmeans = KMeans(n_clusters=i)
        kmeans.fit(data)
        # SSE 값 저장
        sse.append(kmeans.inertia_)
    plt.plot(range(1, length), sse, 'bo-')
    plt.title("elbow method")
    plt.xlabel("number of clusters")
    plt.ylabel("SSE")
    plt.show()
elbow(train_x, 10)

# %%
kmeans_train = train_x
kmeans = KMeans(n_clusters=3, random_state=42).fit(kmeans_train)
train_x['cluster'] = kmeans.predict(kmeans_train)
test_x['cluster'] = kmeans.predict(test_x)

# %%
train_x
# Out:
#      trait  SNP_01  SNP_02  SNP_03  SNP_04  SNP_05  SNP_06  SNP_07  SNP_08  \
# 0        2       5       1       0       4       2       0       0       5
# 1        2       1       1       2       0       0       1       0       4
# 2        2       5       5       0       4       3       5       0       4
# 3        1       0       5       0       4       0       5       5       0
# 4        2       5       5       3       0       3       0       0       0
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 257      2       1       1       0       4       3       1       0       4
# 258      2       5       0       2       0       0       1       4       4
# 259      1       1       5       0       4       0       1       5       4
# 260      1       0       5       0       4       0       5       5       0
# 261      2       5       1       2       5       3       1       0       0
#
#      SNP_09  SNP_10  SNP_11  SNP_12  SNP_13  SNP_14  SNP_15  cluster
# 0         0       5       1       0       0       0       0        2
# 1         0       1       0       4       5       0       0        0
# 2         4       1       0       0       0       0       0        2
# 3         5       1       5       5       5       0       5        1
# 4         0       5       0       0       1       0       4        0
# ..      ...     ...     ...     ...     ...     ...     ...      ...
# 257       0       5       1       4       0       0       0        2
# 258       0       1       1       0       1       0       4        0
# 259       4       0       5       5       5       2       5        1
# 260       4       1       1       4       5       2       5        1
# 261       0       5       0       0       5       0       4        0
#
# [262 rows x 17 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.2)

# %%
X_train
# Out:
#      trait  SNP_01  SNP_02  SNP_03  SNP_04  SNP_05  SNP_06  SNP_07  SNP_08  \
# 16       1       0       5       0       5       0       5       5       0
# 236      2       1       1       3       4       2       1       0       5
# 70       2       1       0       2       0       2       1       0       4
# 29       1       1       5       0       4       0       5       5       0
# 132      2       5       5       3       4       2       5       0       5
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2        2       5       5       0       4       3       5       0       4
# 21       2       5       1       3       0       3       1       0       5
# 207      2       5       1       2       5       2       5       0       4
# 83       1       1       5       0       4       0       5       5       0
# 6        2       5       1       2       4       0       1       0       5
#
#      SNP_09  SNP_10  SNP_11  SNP_12  SNP_13  SNP_14  SNP_15  cluster
# 16        4       5       1       5       5       2       5        1
# 236       4       5       1       0       5       0       0        2
# 70        0       1       0       0       5       0       0        0
# 29        4       0       5       5       5       0       5        1
# 132       0       5       5       0       5       0       4        2
# ..      ...     ...     ...     ...     ...     ...     ...      ...
# 2         4       1       0       0       0       0       0        2
# 21        0       5       5       0       1       0       4        2
# 207       4       5       1       0       1       0       0        2
# 83        4       0       5       5       5       3       5        1
# 6         0       5       1       0       1       0       0        2
#
# [209 rows x 17 columns]

# %%
seed = 42
n_fold = 10   #FOLD 10
n_class = 3
X = train_x
y = train_y
X_test = X_test

# %%
skfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)
folds=[]
for train_idx, valid_idx in skfold.split(train_x, train_y):
        folds.append((train_idx, valid_idx))

cat_pred = np.zeros((X.shape[0], n_class))
cat_pred_test = np.zeros((X_test.shape[0], n_class))
cat_cols = ['trait','SNP_01','SNP_02','SNP_03','SNP_04','SNP_05','SNP_06','SNP_07','SNP_08','SNP_09','SNP_10','SNP_11','SNP_12','SNP_13','SNP_14','SNP_15','cluster']
for fold in range(n_fold):
  print(f'\n----------------- Fold {fold} -----------------\n')
  train_idx, valid_idx = folds[fold]
  X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y[train_idx], y[valid_idx]
  train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
    
  valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

  model_cat = CatBoostClassifier(n_estimators= 10000, eta =0.007, max_depth =3) # n_estimators= 1500, eta =0.02, max_depth = 6,  eval_metric='AUC'
  model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=50, verbose=100)
  

  #cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
  #cat_pred_test += model_cat.predict_proba(X_test) / n_fold
  #print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')
# Out:
# ----------------- Fold 0 -----------------
#
# 0:	learn: 1.0900765	test: 1.0894279	best: 1.0894279 (0)	total: 147ms	remaining: 24m 27s
# 100:	learn: 0.6383491	test: 0.6121397	best: 0.6121397 (100)	total: 1.35s	remaining: 2m 11s
# 200:	learn: 0.4462924	test: 0.4177494	best: 0.4177494 (200)	total: 2.7s	remaining: 2m 11s
# 300:	learn: 0.3428923	test: 0.3199786	best: 0.3199786 (300)	total: 4.16s	remaining: 2m 14s
# 400:	learn: 0.2820051	test: 0.2648499	best: 0.2648499 (400)	total: 5.69s	remaining: 2m 16s
# 500:	learn: 0.2440504	test: 0.2328430	best: 0.2328430 (500)	total: 6.99s	remaining: 2m 12s
# 600:	learn: 0.2159716	test: 0.2076899	best: 0.2076899 (600)	total: 8.2s	remaining: 2m 8s
# 700:	learn: 0.1957183	test: 0.1909496	best: 0.1909496 (700)	total: 9.44s	remaining: 2m 5s
# 800:	learn: 0.1812231	test: 0.1795098	best: 0.1795098 (800)	total: 10.7s	remaining: 2m 2s
# 900:	learn: 0.1692097	test: 0.1695387	best: 0.1695387 (900)	total: 11.9s	remaining: 2m
# 1000:	learn: 0.1599024	test: 0.1621884	best: 0.1621428 (998)	total: 13.2s	remaining: 1m 58s
# 1100:	learn: 0.1518687	test: 0.1566022	best: 0.1565542 (1099)	total: 14.4s	remaining: 1m 56s
# 1200:	learn: 0.1455356	test: 0.1509120	best: 0.1509120 (1200)	total: 15.6s	remaining: 1m 54s
# 1300:	learn: 0.1392079	test: 0.1467964	best: 0.1467508 (1298)	total: 16.8s	remaining: 1m 52s
# 1400:	learn: 0.1338907	test: 0.1434504	best: 0.1434504 (1400)	total: 18.9s	remaining: 1m 56s
# 1500:	learn: 0.1289936	test: 0.1405523	best: 0.1405205 (1498)	total: 20.4s	remaining: 1m 55s
# 1600:	learn: 0.1247528	test: 0.1378562	best: 0.1377853 (1597)	total: 21.8s	remaining: 1m 54s
# 1700:	learn: 0.1204631	test: 0.1352848	best: 0.1352848 (1700)	total: 23.1s	remaining: 1m 52s
# 1300:	learn: 0.1379304	test: 0.2628071	best: 0.2625838 (1289)	total: 23s	remaining: 2m 33s
# 1400:	learn: 0.1322304	test: 0.2609293	best: 0.2606286 (1389)	total: 24.4s	remaining: 2m 29s
# 1500:	learn: 0.1274153	test: 0.2584205	best: 0.2582617 (1481)	total: 25.7s	remaining: 2m 25s
# 1600:	learn: 0.1228660	test: 0.2563628	best: 0.2557606 (1588)	total: 27.1s	remaining: 2m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.2557606128
# bestIteration = 1588
#
# Shrink model to first 1589 iterations.
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0900849	test: 1.0916540	best: 1.0916540 (0)	total: 10.6ms	remaining: 1m 46s
# 100:	learn: 0.6250330	test: 0.7378752	best: 0.7378752 (100)	total: 1.72s	remaining: 2m 49s
# 200:	learn: 0.4445782	test: 0.5804871	best: 0.5804871 (200)	total: 4.65s	remaining: 3m 46s
# 300:	learn: 0.3463841	test: 0.4866610	best: 0.4866610 (300)	total: 10.2s	remaining: 5m 30s
# 400:	learn: 0.2831444	test: 0.4235103	best: 0.4235103 (400)	total: 13.8s	remaining: 5m 29s
# 500:	learn: 0.2414160	test: 0.3803014	best: 0.3803014 (500)	total: 16.4s	remaining: 5m 10s
# 600:	learn: 0.2144459	test: 0.3500479	best: 0.3500152 (599)	total: 21s	remaining: 5m 28s
# 700:	learn: 0.1944619	test: 0.3273672	best: 0.3272439 (699)	total: 28.3s	remaining: 6m 15s
# 800:	learn: 0.1792289	test: 0.3116707	best: 0.3116707 (800)	total: 35s	remaining: 6m 42s
# 900:	learn: 0.1682682	test: 0.3011773	best: 0.3011710 (899)	total: 37.7s	remaining: 6m 20s
# 1000:	learn: 0.1581951	test: 0.2914548	best: 0.2914548 (1000)	total: 39.1s	remaining: 5m 51s
# 1100:	learn: 0.1505287	test: 0.2867508	best: 0.2867021 (1098)	total: 40.4s	remaining: 5m 26s
# 1200:	learn: 0.1442844	test: 0.2814593	best: 0.2814593 (1200)	total: 41.8s	remaining: 5m 6s
# 1300:	learn: 0.1389339	test: 0.2773566	best: 0.2773566 (1300)	total: 43.3s	remaining: 4m 49s
# 1400:	learn: 0.1342069	test: 0.2730151	best: 0.2730151 (1400)	total: 44.8s	remaining: 4m 35s
# 1500:	learn: 0.1287088	test: 0.2721160	best: 0.2717918 (1493)	total: 46.3s	remaining: 4m 22s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.2713237311
# bestIteration = 1515
#
# Shrink model to first 1516 iterations.
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0903046	test: 1.0891041	best: 1.0891041 (0)	total: 10.5ms	remaining: 1m 44s
# 100:	learn: 0.6444411	test: 0.5888260	best: 0.5888260 (100)	total: 1.49s	remaining: 2m 26s
# 200:	learn: 0.4608908	test: 0.3949548	best: 0.3949548 (200)	total: 6.06s	remaining: 4m 55s
# 300:	learn: 0.3581498	test: 0.2957779	best: 0.2957779 (300)	total: 7.71s	remaining: 4m 8s
# 2500:	learn: 0.1059058	test: 0.1631551	best: 0.1630593 (2499)	total: 55.7s	remaining: 2m 46s
# 2600:	learn: 0.1034563	test: 0.1613934	best: 0.1613437 (2599)	total: 58.8s	remaining: 2m 47s
# 2700:	learn: 0.1010594	test: 0.1596853	best: 0.1595910 (2695)	total: 1m	remaining: 2m 43s
# 2800:	learn: 0.0987048	test: 0.1584484	best: 0.1581522 (2777)	total: 1m 2s	remaining: 2m 40s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.1581521799
# bestIteration = 2777
#
# Shrink model to first 2778 iterations.
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0899912	test: 1.0903191	best: 1.0903191 (0)	total: 13.8ms	remaining: 2m 17s
# 100:	learn: 0.6298377	test: 0.6579323	best: 0.6579323 (100)	total: 1.43s	remaining: 2m 20s
# 200:	learn: 0.4479036	test: 0.4873573	best: 0.4873573 (200)	total: 3.05s	remaining: 2m 28s
# 300:	learn: 0.3473652	test: 0.3909844	best: 0.3909844 (300)	total: 4.63s	remaining: 2m 29s

# %%
print(model_cat.get_all_params())
# Out:
# {'nan_mode': 'Min', 'eval_metric': 'MultiClass', 'combinations_ctr': ['Borders:CtrBorderCount=15:CtrBorderType=Uniform:TargetBorderCount=2:TargetBorderType=MinEntropy:Prior=0/1:Prior=0.5/1:Prior=1/1', 'Counter:CtrBorderCount=15:CtrBorderType=Uniform:Prior=0/1'], 'iterations': 10000, 'sampling_frequency': 'PerTree', 'fold_permutation_block': 0, 'leaf_estimation_method': 'Newton', 'od_pval': 0, 'counter_calc_method': 'SkipTest', 'grow_policy': 'SymmetricTree', 'penalties_coefficient': 1, 'boosting_type': 'Plain', 'model_shrink_mode': 'Constant', 'feature_border_type': 'GreedyLogSum', 'ctr_leaf_count_limit': 18446744073709551615, 'bayesian_matrix_reg': 0.10000000149011612, 'one_hot_max_size': 2, 'eval_fraction': 0, 'force_unit_auto_pair_weights': False, 'l2_leaf_reg': 3, 'random_strength': 1, 'od_type': 'Iter', 'rsm': 1, 'boost_from_average': False, 'max_ctr_complexity': 4, 'model_size_reg': 0.5, 'simple_ctr': ['Borders:CtrBorderCount=15:CtrBorderType=Uniform:TargetBorderCount=2:TargetBorderType=MinEntropy:Prior=0/1:Prior=0.5/1:Prior=1/1', 'Counter:CtrBorderCount=15:CtrBorderType=Uniform:Prior=0/1'], 'pool_metainfo_options': {'tags': {}}, 'use_best_model': True, 'od_wait': 50, 'class_names': [0, 1, 2], 'random_seed': 0, 'depth': 3, 'ctr_target_border_count': 1, 'posterior_sampling': False, 'has_time': False, 'store_all_simple_ctr': False, 'border_count': 254, 'bagging_temperature': 1, 'classes_count': 0, 'auto_class_weights': 'None', 'sparse_features_conflict_fraction': 0, 'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'model_shrink_rate': 0, 'min_data_in_leaf': 1, 'loss_function': 'MultiClass', 'learning_rate': 0.007000000216066837, 'score_function': 'Cosine', 'task_type': 'CPU', 'leaf_estimation_iterations': 1, 'bootstrap_type': 'Bayesian', 'max_leaves': 8, 'permutation_count': 4}

# %%
preds = model_cat.predict(X_test)
print('Done.')
# Out:
# Done.

# %%
from sklearn.metrics import accuracy_score as acc
acc(y_test, preds)
# Out:
# 1.0

# %%
preds = model_cat.predict(train_x)
print('Done.')
acc(train_y, preds)
# Out:
# Done.
# 0.9694656488549618

# %%
preds = model_cat.predict(test_x)
print('Done.')
print(preds)
# Out:
# Done.
# [[0]
#  [1]
#  [2]
#  [1]
#  [0]
#  [1]
#  [2]
#  [1]
#  [0]
#  [0]
#  [2]
#  [1]
#  [1]
#  [0]
#  [1]
#  [1]
#  [0]
#  [1]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [0]
#  [1]
#  [1]
#  [1]
#  [0]
#  [0]
#  [1]
#  [0]
#  [0]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [1]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [1]
#  [2]
#  [1]
#  [2]
#  [0]
#  [1]
#  [0]
#  [1]
#  [1]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [2]
#  [2]
#  [0]
#  [1]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [0]
#  [0]
#  [2]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [2]
#  [1]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]
#  [1]
#  [2]
#  [0]
#  [1]
#  [1]
#  [2]
#  [1]
#  [1]
#  [2]
#  [0]
#  [1]
#  [0]
#  [2]
#  [0]
#  [1]
#  [1]
#  [2]
#  [0]
#  [0]
#  [2]
#  [1]
#  [0]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [1]
#  [0]
#  [0]
#  [2]
#  [1]
#  [2]
#  [0]
#  [1]
#  [1]
#  [2]
#  [2]
#  [1]
#  [1]
#  [1]
#  [0]
#  [1]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [2]
#  [0]
#  [0]
#  [1]
#  [0]
#  [0]
#  [0]
#  [2]
#  [1]
#  [1]
#  [1]
#  [0]
#  [1]
#  [2]
#  [0]
#  [0]
#  [1]
#  [0]
#  [1]
#  [1]
#  [0]
#  [0]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [2]
#  [1]
#  [0]
#  [0]
#  [2]
#  [1]
#  [1]
#  [0]
#  [1]
#  [2]
#  [2]
#  [1]
#  [1]]

# %%
def plot_feature_importance(importance,names,model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(10,8))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')

# %%
plot_feature_importance(model_cat.get_feature_importance(),X_test.columns,'CATBOOST')

# %%
submit = pd.read_csv('./sample_submission.csv')

submit['class'] = class_le.inverse_transform(preds)

submit.to_csv('./answer/catnotrait_10_10000_007.csv', index=False)

# %%
an1 = pd.read_csv('./answer/catkmean4_10_10000_007.csv')

# %%
an2 = pd.read_csv('./answer/catfindepth3_10_10000_005.csv')

# %%
an1= an1.drop(columns=['id'])

# %%
an2=an2.drop(columns=['id'])

# %%
an1 = class_le.fit_transform(an1)
an2 = class_le.fit_transform(an2)

# %%
acc(an1, preds)
# Out:
# 0.9942857142857143

# %%
n_fold=5

# %%
skfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)
folds=[]
for train_idx, valid_idx in skfold.split(X, y):
        folds.append((train_idx, valid_idx))

cat_pred = np.zeros((X.shape[0], n_class))
cat_pred_test = np.zeros((X_test.shape[0], n_class))
cat_cols = ['trait','SNP_01','SNP_02','SNP_03','SNP_04','SNP_05','SNP_06','SNP_07','SNP_08','SNP_09','SNP_10','SNP_11','SNP_12','SNP_13','SNP_14','SNP_15']
for fold in range(n_fold):
  print(f'\n----------------- Fold {fold} -----------------\n')
  train_idx, valid_idx = folds[fold]
  X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y[train_idx], y[valid_idx]
  train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
  valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

  model_cat2 = CatBoostClassifier()
  model_cat2.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=150, verbose=100)
  
  cat_pred[valid_idx] = model_cat2.predict_proba(X_valid)
  cat_pred_test += model_cat2.predict_proba(X_test) / n_fold
  print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')
    
print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
# Out:
# ----------------- Fold 0 -----------------
#
# Learning rate set to 0.104648
# 0:	learn: 1.0102712	test: 0.9991774	best: 0.9991774 (0)	total: 180ms	remaining: 2m 59s
# 100:	learn: 0.0927993	test: 0.1513552	best: 0.1512946 (99)	total: 5.24s	remaining: 46.6s
# 200:	learn: 0.0451374	test: 0.1398316	best: 0.1392483 (193)	total: 10.7s	remaining: 42.4s
# 300:	learn: 0.0287371	test: 0.1387561	best: 0.1350914 (267)	total: 15.8s	remaining: 36.8s
# 400:	learn: 0.0204573	test: 0.1336430	best: 0.1326646 (368)	total: 21s	remaining: 31.4s
# 500:	learn: 0.0157875	test: 0.1322404	best: 0.1318873 (495)	total: 26.3s	remaining: 26.2s
# 600:	learn: 0.0128225	test: 0.1318689	best: 0.1313551 (588)	total: 31.4s	remaining: 20.9s
# 700:	learn: 0.0106316	test: 0.1313889	best: 0.1307199 (681)	total: 36.6s	remaining: 15.6s
# 800:	learn: 0.0089997	test: 0.1315337	best: 0.1306355 (739)	total: 41.9s	remaining: 10.4s
# 900:	learn: 0.0078213	test: 0.1315204	best: 0.1305224 (874)	total: 47.2s	remaining: 5.18s
# 999:	learn: 0.0069268	test: 0.1309333	best: 0.1305224 (874)	total: 52.4s	remaining: 0us
#
# bestTest = 0.1305223623
# bestIteration = 874
#
# Shrink model to first 875 iterations.
# CV Log Loss Score: 0.130522
#
# ----------------- Fold 1 -----------------
#
# Learning rate set to 0.104648
# 0:	learn: 0.9994953	test: 1.0081685	best: 1.0081685 (0)	total: 13.7ms	remaining: 13.7s
# 100:	learn: 0.1052256	test: 0.2569198	best: 0.2569198 (100)	total: 4.98s	remaining: 44.3s
# 200:	learn: 0.0504542	test: 0.2422868	best: 0.2422868 (200)	total: 10.1s	remaining: 40.1s
# 300:	learn: 0.0320528	test: 0.2437660	best: 0.2415334 (273)	total: 15.3s	remaining: 35.6s
# 400:	learn: 0.0223291	test: 0.2502221	best: 0.2415334 (273)	total: 20.5s	remaining: 30.7s
# Stopped by overfitting detector  (150 iterations wait)
#
# bestTest = 0.2415333511
# bestIteration = 273
#
# Shrink model to first 274 iterations.
# CV Log Loss Score: 0.241533
#
# ----------------- Fold 2 -----------------
#
# Learning rate set to 0.104658
# 0:	learn: 1.0058407	test: 0.9994944	best: 0.9994944 (0)	total: 21.7ms	remaining: 21.7s
# 100:	learn: 0.0919205	test: 0.2348489	best: 0.2337060 (99)	total: 4.94s	remaining: 44s
# 200:	learn: 0.0455804	test: 0.2237263	best: 0.2225434 (182)	total: 10.2s	remaining: 40.6s
# 300:	learn: 0.0297234	test: 0.2194592	best: 0.2182117 (239)	total: 15.5s	remaining: 36s
# Stopped by overfitting detector  (150 iterations wait)
#
# bestTest = 0.2182117003
# bestIteration = 239
#
# Shrink model to first 240 iterations.
# CV Log Loss Score: 0.218212
#
# ----------------- Fold 3 -----------------
#
# Learning rate set to 0.104658
# 0:	learn: 1.0094461	test: 1.0016478	best: 1.0016478 (0)	total: 22.7ms	remaining: 22.7s
# 100:	learn: 0.0984821	test: 0.2132111	best: 0.2117813 (94)	total: 5.93s	remaining: 52.8s
# 200:	learn: 0.0480685	test: 0.1896747	best: 0.1885996 (179)	total: 12.3s	remaining: 48.9s
# 300:	learn: 0.0310069	test: 0.1866195	best: 0.1852478 (286)	total: 18.1s	remaining: 42s
# 400:	learn: 0.0219696	test: 0.1874876	best: 0.1844881 (315)	total: 23.4s	remaining: 35s
# Stopped by overfitting detector  (150 iterations wait)
#
# bestTest = 0.18448809
# bestIteration = 315
#
# Shrink model to first 316 iterations.
# CV Log Loss Score: 0.184488
#
# ----------------- Fold 4 -----------------
#
# Learning rate set to 0.104658
# 0:	learn: 0.9965878	test: 1.0178584	best: 1.0178584 (0)	total: 31.8ms	remaining: 31.7s
# 100:	learn: 0.1110939	test: 0.1716911	best: 0.1716911 (100)	total: 4.89s	remaining: 43.5s
# 200:	learn: 0.0542347	test: 0.1402842	best: 0.1402389 (199)	total: 10s	remaining: 39.8s
# 300:	learn: 0.0322909	test: 0.1222140	best: 0.1218081 (299)	total: 15.1s	remaining: 35.1s
# 400:	learn: 0.0224361	test: 0.1099871	best: 0.1099871 (400)	total: 20.3s	remaining: 30.3s
# 500:	learn: 0.0172313	test: 0.1061470	best: 0.1061470 (500)	total: 25.4s	remaining: 25.3s
# 600:	learn: 0.0139625	test: 0.1023582	best: 0.1023582 (600)	total: 31s	remaining: 20.6s
# 700:	learn: 0.0117077	test: 0.1004805	best: 0.1004247 (697)	total: 36.3s	remaining: 15.5s
# 800:	learn: 0.0100728	test: 0.0964944	best: 0.0964944 (800)	total: 41.5s	remaining: 10.3s
# 900:	learn: 0.0088892	test: 0.0952487	best: 0.0952277 (899)	total: 46.7s	remaining: 5.13s
# 999:	learn: 0.0078654	test: 0.0926090	best: 0.0925741 (998)	total: 52.1s	remaining: 0us
#
# bestTest = 0.09257414711
# bestIteration = 998
#
# Shrink model to first 999 iterations.
# CV Log Loss Score: 0.092574
# 	Log Loss: 0.173562

# %%
preds2 = model_cat2.predict(X_test)
print('Done.')
# Out:
# Done.

# %%
from sklearn.metrics import accuracy_score as acc
acc(y_test, preds2)
# Out:
# 0.9811320754716981

# %%
preds2 = model_cat2.predict(test_x)
print('Done.')
print(preds2)
# Out:
# Done.
# [[0]
#  [1]
#  [2]
#  [1]
#  [0]
#  [1]
#  [2]
#  [1]
#  [0]
#  [0]
#  [2]
#  [1]
#  [1]
#  [0]
#  [1]
#  [1]
#  [0]
#  [1]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [0]
#  [1]
#  [1]
#  [1]
#  [0]
#  [0]
#  [1]
#  [0]
#  [0]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [1]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [1]
#  [2]
#  [1]
#  [2]
#  [0]
#  [1]
#  [0]
#  [1]
#  [1]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [2]
#  [2]
#  [0]
#  [1]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [0]
#  [0]
#  [2]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [2]
#  [1]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]
#  [1]
#  [2]
#  [0]
#  [1]
#  [1]
#  [2]
#  [1]
#  [1]
#  [2]
#  [0]
#  [1]
#  [0]
#  [2]
#  [0]
#  [1]
#  [1]
#  [2]
#  [0]
#  [0]
#  [2]
#  [1]
#  [0]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [1]
#  [0]
#  [0]
#  [2]
#  [1]
#  [1]
#  [0]
#  [1]
#  [1]
#  [2]
#  [2]
#  [1]
#  [1]
#  [1]
#  [0]
#  [1]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [2]
#  [0]
#  [0]
#  [1]
#  [0]
#  [0]
#  [0]
#  [2]
#  [1]
#  [1]
#  [1]
#  [0]
#  [1]
#  [2]
#  [0]
#  [0]
#  [1]
#  [0]
#  [1]
#  [1]
#  [0]
#  [0]
#  [1]
#  [2]
#  [0]
#  [1]
#  [2]
#  [1]
#  [1]
#  [0]
#  [0]
#  [2]
#  [1]
#  [1]
#  [0]
#  [1]
#  [2]
#  [2]
#  [1]
#  [1]]

# %%
acc(preds2, preds)
# Out:
# 1.0
